# %%
import json
import joblib
import pandas as pd
import tensorflow as tf
from tensorflow.keras import Input, Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Nadam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import AUC, Recall
from utils import get_data_path, get_save_path, save_json

# %% [markdown]
# # === Load processed data ===

# %%
# 讀取資料
X_train = pd.read_csv(get_data_path("X_train_deep.csv"))
y_train = pd.read_csv(get_data_path("y_train.csv")).squeeze()
X_val = pd.read_csv(get_data_path("X_val_deep.csv"))
y_val = pd.read_csv(get_data_path("y_val.csv")).squeeze()
input_dim = X_train.shape[1]

# %% [markdown]
# # === Load best hyperparameters ===

# %%
with open(get_data_path("best_hyperparameters_dense.json")) as f:
    best_hp_dense = json.load(f)
with open(get_data_path("best_hyperparameters_widedeep.json")) as f:
    best_hp_wd = json.load(f)

# %% [markdown]
# # === Build Final Dense Feedforward Model ===

# %%
def build_best_dense_model(hp):
    model = Sequential()
    model.add(Input(shape=(input_dim,)))
    for i in range(hp['num_layers']):
        model.add(Dense(hp[f'units_{i}'], activation=hp['activation']))
        if hp.get(f'use_bn_{i}', False):
            model.add(BatchNormalization())
        model.add(Dropout(hp[f'dropout_{i}']))
    model.add(Dense(1, activation='sigmoid'))

    lr = hp['learning_rate']
    if hp['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=lr)
    elif hp['optimizer'] == 'rmsprop':
        optimizer = RMSprop(learning_rate=lr)
    elif hp['optimizer'] == 'sgd':
        optimizer = SGD(learning_rate=lr)
    else:
        optimizer = Nadam(learning_rate=lr)

    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=["accuracy", Recall(name="recall"), AUC(name="AUC")])
    return model

# %% [markdown]
# # === Build Final Wide & Deep Model ===

# %%
def build_best_wide_and_deep_model(hp):
    input_layer = Input(shape=(input_dim,))
    deep = input_layer
    for i in range(hp['num_layers']):
        deep = Dense(hp[f'units_{i}'], activation=hp['activation'])(deep)
        if hp.get(f'use_bn_{i}', False):
            deep = BatchNormalization()(deep)
        deep = Dropout(hp[f'dropout_{i}'])(deep)

    combined = Concatenate()([input_layer, deep])
    output = Dense(1, activation='sigmoid')(combined)
    model = Model(inputs=input_layer, outputs=output)

    lr = hp['learning_rate']
    if hp['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=lr)
    elif hp['optimizer'] == 'rmsprop':
        optimizer = RMSprop(learning_rate=lr)
    elif hp['optimizer'] == 'sgd':
        optimizer = SGD(learning_rate=lr)
    else:
        optimizer = Nadam(learning_rate=lr)

    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=["accuracy", Recall(name="recall"), AUC(name="AUC")])
    return model

# %% [markdown]
# # === Training Loop ===

# %%
# 設定 EarlyStopping
early_stop = EarlyStopping(monitor="val_AUC", mode="max", patience=10, restore_best_weights=True)

# 訓練 Dense 模型
dense_model = build_best_dense_model(best_hp_dense)
history_dense = dense_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=best_hp_dense.get("batch_size", 32),
    callbacks=[early_stop],
    verbose=2
)
dense_model.save(get_save_path("final_model_dense.keras"))


# 儲存 Dense history
joblib.dump(history_dense.history, get_save_path("history_dense.pkl"))

# 訓練 Wide & Deep 模型
wd_model = build_best_wide_and_deep_model(best_hp_wd)
history_wd = wd_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=best_hp_wd.get("batch_size", 32),
    callbacks=[early_stop],
    verbose=2
)
wd_model.save(get_save_path("final_model_widedeep.keras"))

# 儲存 Wide & Deep history
joblib.dump(history_wd.history, get_save_path("history_widedeep.pkl"))
# Out:
# Epoch 1/100
# 958/958 - 3s - 3ms/step - AUC: 0.5461 - accuracy: 0.6839 - loss: 0.6367 - recall: 0.1048 - val_AUC: 0.6120 - val_accuracy: 0.7110 - val_loss: 0.5871 - val_recall: 0.0082
# Epoch 2/100
# 958/958 - 1s - 744us/step - AUC: 0.5985 - accuracy: 0.7113 - loss: 0.5907 - recall: 0.0359 - val_AUC: 0.6232 - val_accuracy: 0.7110 - val_loss: 0.5816 - val_recall: 0.0173
# Epoch 3/100
# 958/958 - 1s - 738us/step - AUC: 0.6146 - accuracy: 0.7120 - loss: 0.5853 - recall: 0.0435 - val_AUC: 0.6181 - val_accuracy: 0.7118 - val_loss: 0.5858 - val_recall: 0.0214
# Epoch 4/100
# 958/958 - 1s - 797us/step - AUC: 0.6203 - accuracy: 0.7129 - loss: 0.5830 - recall: 0.0472 - val_AUC: 0.6280 - val_accuracy: 0.7099 - val_loss: 0.5802 - val_recall: 0.0211
# Epoch 5/100
# 958/958 - 1s - 731us/step - AUC: 0.6290 - accuracy: 0.7136 - loss: 0.5797 - recall: 0.0457 - val_AUC: 0.6242 - val_accuracy: 0.7105 - val_loss: 0.5826 - val_recall: 0.0133
# Epoch 6/100
# 958/958 - 1s - 722us/step - AUC: 0.6336 - accuracy: 0.7126 - loss: 0.5783 - recall: 0.0497 - val_AUC: 0.6320 - val_accuracy: 0.7094 - val_loss: 0.5791 - val_recall: 0.0306
# Epoch 7/100
# 958/958 - 1s - 729us/step - AUC: 0.6392 - accuracy: 0.7134 - loss: 0.5763 - recall: 0.0547 - val_AUC: 0.6313 - val_accuracy: 0.7104 - val_loss: 0.5804 - val_recall: 0.0418
# Epoch 8/100
# 958/958 - 1s - 726us/step - AUC: 0.6401 - accuracy: 0.7138 - loss: 0.5756 - recall: 0.0612 - val_AUC: 0.6329 - val_accuracy: 0.7076 - val_loss: 0.5809 - val_recall: 0.0605
# Epoch 9/100
# 958/958 - 1s - 728us/step - AUC: 0.6462 - accuracy: 0.7147 - loss: 0.5737 - recall: 0.0639 - val_AUC: 0.6373 - val_accuracy: 0.7071 - val_loss: 0.5795 - val_recall: 0.0469
# Epoch 10/100
# 958/958 - 1s - 722us/step - AUC: 0.6528 - accuracy: 0.7162 - loss: 0.5713 - recall: 0.0756 - val_AUC: 0.6346 - val_accuracy: 0.7100 - val_loss: 0.5789 - val_recall: 0.0207
# Epoch 11/100
# 958/958 - 1s - 722us/step - AUC: 0.6541 - accuracy: 0.7151 - loss: 0.5708 - recall: 0.0697 - val_AUC: 0.6329 - val_accuracy: 0.7102 - val_loss: 0.5819 - val_recall: 0.0398
# Epoch 12/100
# 958/958 - 1s - 722us/step - AUC: 0.6569 - accuracy: 0.7162 - loss: 0.5692 - recall: 0.0808 - val_AUC: 0.6354 - val_accuracy: 0.7107 - val_loss: 0.5795 - val_recall: 0.0401
# Epoch 13/100
# 958/958 - 1s - 725us/step - AUC: 0.6884 - accuracy: 0.7225 - loss: 0.5534 - recall: 0.1442 - val_AUC: 0.6411 - val_accuracy: 0.7108 - val_loss: 0.5776 - val_recall: 0.0343
# Epoch 27/100
# 958/958 - 1s - 727us/step - AUC: 0.6922 - accuracy: 0.7235 - loss: 0.5519 - recall: 0.1493 - val_AUC: 0.6426 - val_accuracy: 0.7097 - val_loss: 0.5795 - val_recall: 0.0884
# Epoch 28/100
# 958/958 - 1s - 735us/step - AUC: 0.6957 - accuracy: 0.7256 - loss: 0.5492 - recall: 0.1602 - val_AUC: 0.6444 - val_accuracy: 0.7118 - val_loss: 0.5829 - val_recall: 0.0680
# Epoch 29/100
# 958/958 - 1s - 749us/step - AUC: 0.6984 - accuracy: 0.7264 - loss: 0.5485 - recall: 0.1623 - val_AUC: 0.6374 - val_accuracy: 0.7084 - val_loss: 0.5859 - val_recall: 0.0727
# Epoch 30/100
# 958/958 - 1s - 730us/step - AUC: 0.6953 - accuracy: 0.7274 - loss: 0.5495 - recall: 0.1620 - val_AUC: 0.6441 - val_accuracy: 0.7091 - val_loss: 0.5832 - val_recall: 0.1027
# Epoch 1/100
# 240/240 - 3s - 11ms/step - AUC: 0.5409 - accuracy: 0.6435 - loss: 0.6802 - recall: 0.2219 - val_AUC: 0.5742 - val_accuracy: 0.6901 - val_loss: 0.6143 - val_recall: 0.1173
# Epoch 2/100
# 240/240 - 1s - 5ms/step - AUC: 0.5547 - accuracy: 0.6863 - loss: 0.6304 - recall: 0.1107 - val_AUC: 0.5909 - val_accuracy: 0.7028 - val_loss: 0.5982 - val_recall: 0.0690
# Epoch 3/100
# 240/240 - 1s - 6ms/step - AUC: 0.5653 - accuracy: 0.6950 - loss: 0.6164 - recall: 0.0886 - val_AUC: 0.5985 - val_accuracy: 0.7036 - val_loss: 0.5946 - val_recall: 0.0690
# Epoch 4/100
# 240/240 - 1s - 6ms/step - AUC: 0.5766 - accuracy: 0.6991 - loss: 0.6068 - recall: 0.0786 - val_AUC: 0.6045 - val_accuracy: 0.7074 - val_loss: 0.5908 - val_recall: 0.0557
# Epoch 5/100
# 240/240 - 1s - 6ms/step - AUC: 0.5837 - accuracy: 0.7035 - loss: 0.6013 - recall: 0.0699 - val_AUC: 0.6099 - val_accuracy: 0.7088 - val_loss: 0.5880 - val_recall: 0.0551
# Epoch 6/100
# 240/240 - 1s - 6ms/step - AUC: 0.5911 - accuracy: 0.7069 - loss: 0.5964 - recall: 0.0725 - val_AUC: 0.6150 - val_accuracy: 0.7110 - val_loss: 0.5856 - val_recall: 0.0537
# Epoch 7/100
# 240/240 - 1s - 6ms/step - AUC: 0.5924 - accuracy: 0.7046 - loss: 0.5958 - recall: 0.0603 - val_AUC: 0.6163 - val_accuracy: 0.7111 - val_loss: 0.5852 - val_recall: 0.0462
# Epoch 8/100
# 240/240 - 1s - 5ms/step - AUC: 0.5947 - accuracy: 0.7093 - loss: 0.5935 - recall: 0.0564 - val_AUC: 0.6185 - val_accuracy: 0.7106 - val_loss: 0.5844 - val_recall: 0.0479
# Epoch 9/100
# Epoch 22/100
# 240/240 - 2s - 6ms/step - AUC: 0.6299 - accuracy: 0.7128 - loss: 0.5795 - recall: 0.0692 - val_AUC: 0.6307 - val_accuracy: 0.7098 - val_loss: 0.5800 - val_recall: 0.0333
# Epoch 23/100
# 240/240 - 1s - 6ms/step - AUC: 0.6337 - accuracy: 0.7131 - loss: 0.5777 - recall: 0.0595 - val_AUC: 0.6310 - val_accuracy: 0.7119 - val_loss: 0.5798 - val_recall: 0.0432
# Epoch 24/100
# 240/240 - 2s - 6ms/step - AUC: 0.6392 - accuracy: 0.7140 - loss: 0.5758 - recall: 0.0707 - val_AUC: 0.6327 - val_accuracy: 0.7081 - val_loss: 0.5797 - val_recall: 0.0428
# Epoch 25/100
# 240/240 - 2s - 6ms/step - AUC: 0.6399 - accuracy: 0.7160 - loss: 0.5751 - recall: 0.0781 - val_AUC: 0.6324 - val_accuracy: 0.7087 - val_loss: 0.5797 - val_recall: 0.0438
# Epoch 26/100
# 240/240 - 1s - 6ms/step - AUC: 0.6418 - accuracy: 0.7159 - loss: 0.5743 - recall: 0.0757 - val_AUC: 0.6330 - val_accuracy: 0.7096 - val_loss: 0.5801 - val_recall: 0.0404
# Epoch 27/100
# 240/240 - 2s - 7ms/step - AUC: 0.6434 - accuracy: 0.7134 - loss: 0.5742 - recall: 0.0744 - val_AUC: 0.6345 - val_accuracy: 0.7088 - val_loss: 0.5806 - val_recall: 0.0323
# Epoch 28/100
# 240/240 - 2s - 7ms/step - AUC: 0.6461 - accuracy: 0.7140 - loss: 0.5730 - recall: 0.0709 - val_AUC: 0.6331 - val_accuracy: 0.7101 - val_loss: 0.5794 - val_recall: 0.0394
# Epoch 29/100
# 240/240 - 2s - 7ms/step - AUC: 0.6454 - accuracy: 0.7149 - loss: 0.5727 - recall: 0.0782 - val_AUC: 0.6321 - val_accuracy: 0.7111 - val_loss: 0.5793 - val_recall: 0.0435
# Epoch 30/100
# 240/240 - 2s - 6ms/step - AUC: 0.6458 - accuracy: 0.7147 - loss: 0.5728 - recall: 0.0749 - val_AUC: 0.6347 - val_accuracy: 0.7099 - val_loss: 0.5790 - val_recall: 0.0374
# Epoch 31/100
# 240/240 - 2s - 7ms/step - AUC: 0.6481 - accuracy: 0.7157 - loss: 0.5720 - recall: 0.0766 - val_AUC: 0.6359 - val_accuracy: 0.7101 - val_loss: 0.5798 - val_recall: 0.0340
# Epoch 32/100
# 240/240 - 2s - 8ms/step - AUC: 0.6511 - accuracy: 0.7161 - loss: 0.5706 - recall: 0.0826 - val_AUC: 0.6356 - val_accuracy: 0.7082 - val_loss: 0.5798 - val_recall: 0.0350
# Epoch 33/100
# 240/240 - 2s - 7ms/step - AUC: 0.6521 - accuracy: 0.7157 - loss: 0.5703 - recall: 0.0839 - val_AUC: 0.6355 - val_accuracy: 0.7096 - val_loss: 0.5792 - val_recall: 0.0323
# Epoch 34/100
# 240/240 - 2s - 7ms/step - AUC: 0.6511 - accuracy: 0.7158 - loss: 0.5709 - recall: 0.0775 - val_AUC: 0.6365 - val_accuracy: 0.7100 - val_loss: 0.5786 - val_recall: 0.0360
# Epoch 35/100
# 240/240 - 2s - 8ms/step - AUC: 0.6556 - accuracy: 0.7160 - loss: 0.5690 - recall: 0.0836 - val_AUC: 0.6370 - val_accuracy: 0.7102 - val_loss: 0.5793 - val_recall: 0.0384
# Epoch 36/100
# 240/240 - 2s - 6ms/step - AUC: 0.6533 - accuracy: 0.7160 - loss: 0.5701 - recall: 0.0811 - val_AUC: 0.6382 - val_accuracy: 0.7101 - val_loss: 0.5790 - val_recall: 0.0377
# Epoch 37/100
# 240/240 - 1s - 6ms/step - AUC: 0.6580 - accuracy: 0.7172 - loss: 0.5678 - recall: 0.0897 - val_AUC: 0.6365 - val_accuracy: 0.7098 - val_loss: 0.5790 - val_recall: 0.0459
# Epoch 38/100
# 240/240 - 1s - 6ms/step - AUC: 0.6574 - accuracy: 0.7171 - loss: 0.5679 - recall: 0.0883 - val_AUC: 0.6374 - val_accuracy: 0.7097 - val_loss: 0.5794 - val_recall: 0.0472
# Epoch 39/100
# 240/240 - 2s - 6ms/step - AUC: 0.6602 - accuracy: 0.7175 - loss: 0.5670 - recall: 0.0923 - val_AUC: 0.6364 - val_accuracy: 0.7102 - val_loss: 0.5807 - val_recall: 0.0374
# Epoch 40/100
# 240/240 - 2s - 6ms/step - AUC: 0.6641 - accuracy: 0.7201 - loss: 0.5647 - recall: 0.0977 - val_AUC: 0.6373 - val_accuracy: 0.7092 - val_loss: 0.5795 - val_recall: 0.0455
# Epoch 41/100
# 240/240 - 2s - 6ms/step - AUC: 0.6623 - accuracy: 0.7183 - loss: 0.5658 - recall: 0.0997 - val_AUC: 0.6364 - val_accuracy: 0.7092 - val_loss: 0.5809 - val_recall: 0.0472
# Epoch 42/100
# 240/240 - 1s - 6ms/step - AUC: 0.6620 - accuracy: 0.7190 - loss: 0.5657 - recall: 0.0987 - val_AUC: 0.6370 - val_accuracy: 0.7095 - val_loss: 0.5789 - val_recall: 0.0442
# Epoch 43/100
# 240/240 - 1s - 6ms/step - AUC: 0.6668 - accuracy: 0.7173 - loss: 0.5639 - recall: 0.0967 - val_AUC: 0.6369 - val_accuracy: 0.7103 - val_loss: 0.5795 - val_recall: 0.0493
# Epoch 44/100
# 240/240 - 1s - 6ms/step - AUC: 0.6691 - accuracy: 0.7177 - loss: 0.5634 - recall: 0.1020 - val_AUC: 0.6361 - val_accuracy: 0.7097 - val_loss: 0.5809 - val_recall: 0.0523
# Epoch 45/100
# 240/240 - 1s - 6ms/step - AUC: 0.6668 - accuracy: 0.7190 - loss: 0.5640 - recall: 0.1015 - val_AUC: 0.6360 - val_accuracy: 0.7106 - val_loss: 0.5799 - val_recall: 0.0537
# Epoch 46/100
# 240/240 - 1s - 6ms/step - AUC: 0.6657 - accuracy: 0.7188 - loss: 0.5645 - recall: 0.1034 - val_AUC: 0.6377 - val_accuracy: 0.7114 - val_loss: 0.5793 - val_recall: 0.0551
# ['/Users/audreychang/projects/ACTL3143/Project/data/history_widedeep.pkl']
