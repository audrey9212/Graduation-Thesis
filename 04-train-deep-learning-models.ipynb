# %% [markdown]
# # 1. Required Packages

# %%
import json
import joblib
import pandas as pd
import tensorflow as tf
from tensorflow.keras import Input, Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Nadam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import AUC, Recall
from utils import get_data_path, get_save_path, save_json

# %% [markdown]
# # 2. Data Loading

# %%
X_train = pd.read_csv(get_data_path("X_train_deep.csv"))
y_train = pd.read_csv(get_data_path("y_train.csv")).squeeze()
X_val = pd.read_csv(get_data_path("X_val_deep.csv"))
y_val = pd.read_csv(get_data_path("y_val.csv")).squeeze()
input_dim = X_train.shape[1]

# %% [markdown]
# ## Load best hyperparameters

# %%
with open(get_data_path("best_hyperparameters_dense.json")) as f:
    best_hp_dense = json.load(f)
with open(get_data_path("best_hyperparameters_widedeep.json")) as f:
    best_hp_wd = json.load(f)

# %% [markdown]
# # 3. Functions

# %% [markdown]
# ## Build Final Dense Feedforward Model

# %%
def build_best_dense_model(hp):
    model = Sequential()
    model.add(Input(shape=(input_dim,)))
    for i in range(hp['num_layers']):
        model.add(Dense(hp[f'units_{i}'], activation=hp['activation']))
        if hp.get(f'use_bn_{i}', False):
            model.add(BatchNormalization())
        model.add(Dropout(hp[f'dropout_{i}']))
    model.add(Dense(1, activation='sigmoid'))

    lr = hp['learning_rate']
    if hp['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=lr)
    elif hp['optimizer'] == 'rmsprop':
        optimizer = RMSprop(learning_rate=lr)
    elif hp['optimizer'] == 'sgd':
        optimizer = SGD(learning_rate=lr)
    else:
        optimizer = Nadam(learning_rate=lr)

    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=["accuracy", Recall(name="recall"), AUC(name="AUC")])
    return model

# %% [markdown]
# ## Build Final Wide & Deep Model

# %%
def build_best_wide_and_deep_model(hp):
    input_layer = Input(shape=(input_dim,))
    deep = input_layer
    for i in range(hp['num_layers']):
        deep = Dense(hp[f'units_{i}'], activation=hp['activation'])(deep)
        if hp.get(f'use_bn_{i}', False):
            deep = BatchNormalization()(deep)
        deep = Dropout(hp[f'dropout_{i}'])(deep)

    combined = Concatenate()([input_layer, deep])
    output = Dense(1, activation='sigmoid')(combined)
    model = Model(inputs=input_layer, outputs=output)

    lr = hp['learning_rate']
    if hp['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=lr)
    elif hp['optimizer'] == 'rmsprop':
        optimizer = RMSprop(learning_rate=lr)
    elif hp['optimizer'] == 'sgd':
        optimizer = SGD(learning_rate=lr)
    else:
        optimizer = Nadam(learning_rate=lr)

    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=["accuracy", Recall(name="recall"), AUC(name="AUC")])
    return model

# %% [markdown]
# # 4. Training Loop

# %%
# Configure EarlyStopping
early_stop = EarlyStopping(monitor="val_AUC", mode="max", patience=10, restore_best_weights=True)

# Train Dense model
dense_model = build_best_dense_model(best_hp_dense)
history_dense = dense_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=best_hp_dense.get("batch_size", 32),
    callbacks=[early_stop],
    verbose=2
)
dense_model.save(get_save_path("final_model_dense.keras"))

# Save Dense history
joblib.dump(history_dense.history, get_save_path("history_dense.pkl"))

# Train Wide & Deep model
wd_model = build_best_wide_and_deep_model(best_hp_wd)
history_wd = wd_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=best_hp_wd.get("batch_size", 32),
    callbacks=[early_stop],
    verbose=2
)
wd_model.save(get_save_path("final_model_widedeep.keras"))

# Save Wide & Deep history
joblib.dump(history_wd.history, get_save_path("history_widedeep.pkl"))
# Out:
# Epoch 1/100
# 958/958 - 3s - 3ms/step - AUC: 0.5418 - accuracy: 0.6828 - loss: 0.6391 - recall: 0.0964 - val_AUC: 0.6086 - val_accuracy: 0.7113 - val_loss: 0.5872 - val_recall: 0.0415
# Epoch 2/100
# 958/958 - 1s - 1ms/step - AUC: 0.5964 - accuracy: 0.7091 - loss: 0.5918 - recall: 0.0327 - val_AUC: 0.6238 - val_accuracy: 0.7113 - val_loss: 0.5809 - val_recall: 0.0160
# Epoch 3/100
# 958/958 - 1s - 1ms/step - AUC: 0.6172 - accuracy: 0.7120 - loss: 0.5846 - recall: 0.0333 - val_AUC: 0.6266 - val_accuracy: 0.7085 - val_loss: 0.5820 - val_recall: 0.0619
# Epoch 4/100
# 958/958 - 1s - 2ms/step - AUC: 0.6227 - accuracy: 0.7144 - loss: 0.5819 - recall: 0.0560 - val_AUC: 0.6248 - val_accuracy: 0.7106 - val_loss: 0.5832 - val_recall: 0.0248
# Epoch 5/100
# 958/958 - 1s - 1ms/step - AUC: 0.6319 - accuracy: 0.7126 - loss: 0.5795 - recall: 0.0476 - val_AUC: 0.6259 - val_accuracy: 0.7087 - val_loss: 0.5819 - val_recall: 0.0211
# Epoch 6/100
# 958/958 - 1s - 1ms/step - AUC: 0.6349 - accuracy: 0.7122 - loss: 0.5780 - recall: 0.0539 - val_AUC: 0.6291 - val_accuracy: 0.7095 - val_loss: 0.5813 - val_recall: 0.0190
# Epoch 7/100
# 958/958 - 1s - 1ms/step - AUC: 0.6392 - accuracy: 0.7139 - loss: 0.5765 - recall: 0.0606 - val_AUC: 0.6308 - val_accuracy: 0.7078 - val_loss: 0.5825 - val_recall: 0.0602
# Epoch 8/100
# 958/958 - 1s - 1ms/step - AUC: 0.6442 - accuracy: 0.7137 - loss: 0.5742 - recall: 0.0600 - val_AUC: 0.6259 - val_accuracy: 0.7084 - val_loss: 0.5822 - val_recall: 0.0197
# Epoch 9/100
# 958/958 - 1s - 1ms/step - AUC: 0.6463 - accuracy: 0.7133 - loss: 0.5735 - recall: 0.0691 - val_AUC: 0.6300 - val_accuracy: 0.7111 - val_loss: 0.5817 - val_recall: 0.0194
# Epoch 10/100
# 958/958 - 1s - 1ms/step - AUC: 0.6532 - accuracy: 0.7147 - loss: 0.5716 - recall: 0.0751 - val_AUC: 0.6338 - val_accuracy: 0.7077 - val_loss: 0.5851 - val_recall: 0.0452
# Epoch 11/100
# 958/958 - 1s - 1ms/step - AUC: 0.6525 - accuracy: 0.7170 - loss: 0.5707 - recall: 0.0830 - val_AUC: 0.6346 - val_accuracy: 0.7061 - val_loss: 0.5814 - val_recall: 0.0493
# Epoch 12/100
# 958/958 - 1s - 1ms/step - AUC: 0.6587 - accuracy: 0.7157 - loss: 0.5681 - recall: 0.0833 - val_AUC: 0.6322 - val_accuracy: 0.7057 - val_loss: 0.5861 - val_recall: 0.0459
# Epoch 13/100
# 958/958 - 1s - 1ms/step - AUC: 0.6627 - accuracy: 0.7171 - loss: 0.5670 - recall: 0.0941 - val_AUC: 0.6353 - val_accuracy: 0.7090 - val_loss: 0.5805 - val_recall: 0.0476
# Epoch 14/100
# 958/958 - 1s - 1ms/step - AUC: 0.6633 - accuracy: 0.7204 - loss: 0.5649 - recall: 0.1037 - val_AUC: 0.6391 - val_accuracy: 0.7088 - val_loss: 0.5811 - val_recall: 0.0608
# Epoch 15/100
# 958/958 - 1s - 1ms/step - AUC: 0.6649 - accuracy: 0.7177 - loss: 0.5652 - recall: 0.0987 - val_AUC: 0.6420 - val_accuracy: 0.7105 - val_loss: 0.5792 - val_recall: 0.0235
# Epoch 16/100
# 958/958 - 1s - 1ms/step - AUC: 0.6727 - accuracy: 0.7187 - loss: 0.5619 - recall: 0.1094 - val_AUC: 0.6384 - val_accuracy: 0.7095 - val_loss: 0.5831 - val_recall: 0.0387
# Epoch 17/100
# 958/958 - 1s - 1ms/step - AUC: 0.6740 - accuracy: 0.7191 - loss: 0.5615 - recall: 0.1115 - val_AUC: 0.6394 - val_accuracy: 0.7104 - val_loss: 0.5834 - val_recall: 0.0639
# Epoch 18/100
# 958/958 - 1s - 1ms/step - AUC: 0.6766 - accuracy: 0.7229 - loss: 0.5595 - recall: 0.1239 - val_AUC: 0.6411 - val_accuracy: 0.7089 - val_loss: 0.5844 - val_recall: 0.0833
# Epoch 19/100
# 958/958 - 1s - 1ms/step - AUC: 0.6795 - accuracy: 0.7208 - loss: 0.5580 - recall: 0.1306 - val_AUC: 0.6422 - val_accuracy: 0.7114 - val_loss: 0.5816 - val_recall: 0.0544
# Epoch 20/100
# 958/958 - 1s - 1ms/step - AUC: 0.6791 - accuracy: 0.7209 - loss: 0.5584 - recall: 0.1179 - val_AUC: 0.6435 - val_accuracy: 0.7096 - val_loss: 0.5856 - val_recall: 0.0931
# Epoch 21/100
# 958/958 - 1s - 1ms/step - AUC: 0.6820 - accuracy: 0.7245 - loss: 0.5561 - recall: 0.1412 - val_AUC: 0.6428 - val_accuracy: 0.7108 - val_loss: 0.5817 - val_recall: 0.0537
# Epoch 22/100
# 958/958 - 1s - 1ms/step - AUC: 0.6889 - accuracy: 0.7242 - loss: 0.5534 - recall: 0.1383 - val_AUC: 0.6424 - val_accuracy: 0.7104 - val_loss: 0.5839 - val_recall: 0.0585
# Epoch 23/100
# 958/958 - 1s - 1ms/step - AUC: 0.6880 - accuracy: 0.7250 - loss: 0.5528 - recall: 0.1438 - val_AUC: 0.6436 - val_accuracy: 0.7092 - val_loss: 0.5859 - val_recall: 0.0738
# Epoch 24/100
# 958/958 - 1s - 1ms/step - AUC: 0.6896 - accuracy: 0.7253 - loss: 0.5525 - recall: 0.1503 - val_AUC: 0.6463 - val_accuracy: 0.7054 - val_loss: 0.5949 - val_recall: 0.1190
# Epoch 25/100
# 958/958 - 1s - 1ms/step - AUC: 0.6933 - accuracy: 0.7265 - loss: 0.5508 - recall: 0.1592 - val_AUC: 0.6446 - val_accuracy: 0.7116 - val_loss: 0.5818 - val_recall: 0.0598
# Epoch 26/100
# 958/958 - 1s - 1ms/step - AUC: 0.6896 - accuracy: 0.7245 - loss: 0.5523 - recall: 0.1457 - val_AUC: 0.6461 - val_accuracy: 0.7093 - val_loss: 0.5789 - val_recall: 0.0748
# Epoch 27/100
# 958/958 - 1s - 1ms/step - AUC: 0.6954 - accuracy: 0.7262 - loss: 0.5496 - recall: 0.1603 - val_AUC: 0.6425 - val_accuracy: 0.7062 - val_loss: 0.5864 - val_recall: 0.0829
# Epoch 28/100
# 958/958 - 1s - 1ms/step - AUC: 0.6927 - accuracy: 0.7265 - loss: 0.5499 - recall: 0.1524 - val_AUC: 0.6414 - val_accuracy: 0.7073 - val_loss: 0.5883 - val_recall: 0.1176
# Epoch 29/100
# 958/958 - 1s - 1ms/step - AUC: 0.6989 - accuracy: 0.7294 - loss: 0.5472 - recall: 0.1700 - val_AUC: 0.6444 - val_accuracy: 0.7072 - val_loss: 0.5982 - val_recall: 0.0999
# Epoch 30/100
# 958/958 - 1s - 1ms/step - AUC: 0.7003 - accuracy: 0.7297 - loss: 0.5459 - recall: 0.1666 - val_AUC: 0.6443 - val_accuracy: 0.7079 - val_loss: 0.5877 - val_recall: 0.0843
# Epoch 31/100
# 958/958 - 1s - 1ms/step - AUC: 0.7020 - accuracy: 0.7286 - loss: 0.5458 - recall: 0.1722 - val_AUC: 0.6432 - val_accuracy: 0.7055 - val_loss: 0.5915 - val_recall: 0.1213
# Epoch 32/100
# 958/958 - 1s - 1ms/step - AUC: 0.7052 - accuracy: 0.7307 - loss: 0.5435 - recall: 0.1765 - val_AUC: 0.6454 - val_accuracy: 0.7080 - val_loss: 0.5920 - val_recall: 0.1061
# Epoch 33/100
# 958/958 - 1s - 1ms/step - AUC: 0.7061 - accuracy: 0.7281 - loss: 0.5431 - recall: 0.1764 - val_AUC: 0.6396 - val_accuracy: 0.7077 - val_loss: 0.5992 - val_recall: 0.0809
# Epoch 34/100
# 958/958 - 1s - 1ms/step - AUC: 0.7045 - accuracy: 0.7326 - loss: 0.5435 - recall: 0.1870 - val_AUC: 0.6436 - val_accuracy: 0.7090 - val_loss: 0.5868 - val_recall: 0.0717
# Epoch 1/100
# 240/240 - 5s - 20ms/step - AUC: 0.5202 - accuracy: 0.6486 - loss: 0.6903 - recall: 0.1859 - val_AUC: 0.5445 - val_accuracy: 0.7014 - val_loss: 0.6164 - val_recall: 0.0421
# Epoch 2/100
# 240/240 - 2s - 10ms/step - AUC: 0.5452 - accuracy: 0.6865 - loss: 0.6379 - recall: 0.1110 - val_AUC: 0.5770 - val_accuracy: 0.7056 - val_loss: 0.6024 - val_recall: 0.0523
# Epoch 3/100
# 240/240 - 3s - 11ms/step - AUC: 0.5556 - accuracy: 0.6951 - loss: 0.6200 - recall: 0.0901 - val_AUC: 0.5913 - val_accuracy: 0.7054 - val_loss: 0.5969 - val_recall: 0.0479
# Epoch 4/100
# 240/240 - 3s - 12ms/step - AUC: 0.5684 - accuracy: 0.7009 - loss: 0.6104 - recall: 0.0795 - val_AUC: 0.6005 - val_accuracy: 0.7087 - val_loss: 0.5930 - val_recall: 0.0466
# Epoch 5/100
# 240/240 - 2s - 9ms/step - AUC: 0.5775 - accuracy: 0.7030 - loss: 0.6039 - recall: 0.0648 - val_AUC: 0.6087 - val_accuracy: 0.7093 - val_loss: 0.5900 - val_recall: 0.0537
# Epoch 6/100
# 240/240 - 2s - 10ms/step - AUC: 0.5800 - accuracy: 0.7053 - loss: 0.6006 - recall: 0.0595 - val_AUC: 0.6119 - val_accuracy: 0.7091 - val_loss: 0.5885 - val_recall: 0.0578
# Epoch 7/100
# 240/240 - 2s - 10ms/step - AUC: 0.5924 - accuracy: 0.7068 - loss: 0.5950 - recall: 0.0602 - val_AUC: 0.6159 - val_accuracy: 0.7084 - val_loss: 0.5871 - val_recall: 0.0496
# Epoch 8/100
# 240/240 - 2s - 10ms/step - AUC: 0.5960 - accuracy: 0.7079 - loss: 0.5936 - recall: 0.0561 - val_AUC: 0.6175 - val_accuracy: 0.7092 - val_loss: 0.5862 - val_recall: 0.0510
# Epoch 9/100
# 240/240 - 2s - 9ms/step - AUC: 0.6015 - accuracy: 0.7084 - loss: 0.5909 - recall: 0.0562 - val_AUC: 0.6204 - val_accuracy: 0.7102 - val_loss: 0.5845 - val_recall: 0.0540
# Epoch 10/100
# 240/240 - 2s - 9ms/step - AUC: 0.6052 - accuracy: 0.7090 - loss: 0.5894 - recall: 0.0500 - val_AUC: 0.6230 - val_accuracy: 0.7098 - val_loss: 0.5836 - val_recall: 0.0581
# Epoch 11/100
# 240/240 - 2s - 9ms/step - AUC: 0.6152 - accuracy: 0.7108 - loss: 0.5857 - recall: 0.0596 - val_AUC: 0.6239 - val_accuracy: 0.7092 - val_loss: 0.5832 - val_recall: 0.0557
# Epoch 12/100
# 240/240 - 2s - 8ms/step - AUC: 0.6148 - accuracy: 0.7118 - loss: 0.5853 - recall: 0.0522 - val_AUC: 0.6246 - val_accuracy: 0.7101 - val_loss: 0.5826 - val_recall: 0.0557
# Epoch 13/100
# 240/240 - 2s - 9ms/step - AUC: 0.6179 - accuracy: 0.7119 - loss: 0.5846 - recall: 0.0566 - val_AUC: 0.6248 - val_accuracy: 0.7099 - val_loss: 0.5829 - val_recall: 0.0581
# Epoch 14/100
# 240/240 - 2s - 9ms/step - AUC: 0.6207 - accuracy: 0.7124 - loss: 0.5833 - recall: 0.0631 - val_AUC: 0.6271 - val_accuracy: 0.7099 - val_loss: 0.5815 - val_recall: 0.0479
# Epoch 15/100
# 240/240 - 2s - 9ms/step - AUC: 0.6241 - accuracy: 0.7123 - loss: 0.5818 - recall: 0.0602 - val_AUC: 0.6275 - val_accuracy: 0.7106 - val_loss: 0.5814 - val_recall: 0.0500
# Epoch 16/100
# 240/240 - 2s - 9ms/step - AUC: 0.6277 - accuracy: 0.7119 - loss: 0.5812 - recall: 0.0577 - val_AUC: 0.6308 - val_accuracy: 0.7093 - val_loss: 0.5798 - val_recall: 0.0401
# Epoch 17/100
# 240/240 - 2s - 9ms/step - AUC: 0.6319 - accuracy: 0.7118 - loss: 0.5793 - recall: 0.0591 - val_AUC: 0.6299 - val_accuracy: 0.7091 - val_loss: 0.5806 - val_recall: 0.0442
# Epoch 18/100
# 240/240 - 2s - 10ms/step - AUC: 0.6278 - accuracy: 0.7142 - loss: 0.5800 - recall: 0.0595 - val_AUC: 0.6310 - val_accuracy: 0.7091 - val_loss: 0.5801 - val_recall: 0.0479
# Epoch 19/100
# 240/240 - 2s - 9ms/step - AUC: 0.6340 - accuracy: 0.7123 - loss: 0.5778 - recall: 0.0568 - val_AUC: 0.6308 - val_accuracy: 0.7091 - val_loss: 0.5800 - val_recall: 0.0510
# Epoch 20/100
# 240/240 - 3s - 11ms/step - AUC: 0.6349 - accuracy: 0.7137 - loss: 0.5777 - recall: 0.0628 - val_AUC: 0.6319 - val_accuracy: 0.7099 - val_loss: 0.5798 - val_recall: 0.0449
# Epoch 21/100
# 240/240 - 2s - 10ms/step - AUC: 0.6370 - accuracy: 0.7134 - loss: 0.5766 - recall: 0.0631 - val_AUC: 0.6308 - val_accuracy: 0.7100 - val_loss: 0.5798 - val_recall: 0.0384
# Epoch 22/100
# 240/240 - 2s - 10ms/step - AUC: 0.6383 - accuracy: 0.7140 - loss: 0.5762 - recall: 0.0602 - val_AUC: 0.6335 - val_accuracy: 0.7101 - val_loss: 0.5794 - val_recall: 0.0398
# Epoch 23/100
# 240/240 - 2s - 10ms/step - AUC: 0.6397 - accuracy: 0.7146 - loss: 0.5759 - recall: 0.0637 - val_AUC: 0.6325 - val_accuracy: 0.7093 - val_loss: 0.5797 - val_recall: 0.0421
# Epoch 24/100
# 240/240 - 2s - 10ms/step - AUC: 0.6414 - accuracy: 0.7140 - loss: 0.5752 - recall: 0.0594 - val_AUC: 0.6326 - val_accuracy: 0.7093 - val_loss: 0.5798 - val_recall: 0.0415
# Epoch 25/100
# 240/240 - 3s - 11ms/step - AUC: 0.6463 - accuracy: 0.7151 - loss: 0.5730 - recall: 0.0715 - val_AUC: 0.6338 - val_accuracy: 0.7083 - val_loss: 0.5794 - val_recall: 0.0493
# Epoch 26/100
# 240/240 - 2s - 10ms/step - AUC: 0.6460 - accuracy: 0.7152 - loss: 0.5731 - recall: 0.0751 - val_AUC: 0.6338 - val_accuracy: 0.7084 - val_loss: 0.5796 - val_recall: 0.0374
# Epoch 27/100
# 240/240 - 2s - 10ms/step - AUC: 0.6461 - accuracy: 0.7154 - loss: 0.5728 - recall: 0.0708 - val_AUC: 0.6347 - val_accuracy: 0.7086 - val_loss: 0.5788 - val_recall: 0.0367
# Epoch 28/100
# 240/240 - 2s - 10ms/step - AUC: 0.6522 - accuracy: 0.7152 - loss: 0.5704 - recall: 0.0768 - val_AUC: 0.6341 - val_accuracy: 0.7079 - val_loss: 0.5802 - val_recall: 0.0432
# Epoch 29/100
# 240/240 - 2s - 9ms/step - AUC: 0.6531 - accuracy: 0.7165 - loss: 0.5704 - recall: 0.0852 - val_AUC: 0.6347 - val_accuracy: 0.7087 - val_loss: 0.5796 - val_recall: 0.0374
# Epoch 30/100
# 240/240 - 2s - 9ms/step - AUC: 0.6530 - accuracy: 0.7157 - loss: 0.5704 - recall: 0.0727 - val_AUC: 0.6340 - val_accuracy: 0.7086 - val_loss: 0.5793 - val_recall: 0.0418
# Epoch 31/100
# 240/240 - 3s - 11ms/step - AUC: 0.6532 - accuracy: 0.7160 - loss: 0.5701 - recall: 0.0827 - val_AUC: 0.6353 - val_accuracy: 0.7064 - val_loss: 0.5796 - val_recall: 0.0452
# Epoch 32/100
# 240/240 - 2s - 9ms/step - AUC: 0.6575 - accuracy: 0.7168 - loss: 0.5685 - recall: 0.0867 - val_AUC: 0.6333 - val_accuracy: 0.7076 - val_loss: 0.5802 - val_recall: 0.0435
# Epoch 33/100
# 240/240 - 2s - 10ms/step - AUC: 0.6586 - accuracy: 0.7156 - loss: 0.5677 - recall: 0.0800 - val_AUC: 0.6323 - val_accuracy: 0.7079 - val_loss: 0.5812 - val_recall: 0.0489
# Epoch 34/100
# 240/240 - 2s - 9ms/step - AUC: 0.6573 - accuracy: 0.7154 - loss: 0.5679 - recall: 0.0837 - val_AUC: 0.6344 - val_accuracy: 0.7074 - val_loss: 0.5804 - val_recall: 0.0435
# Epoch 35/100
# 240/240 - 2s - 9ms/step - AUC: 0.6575 - accuracy: 0.7168 - loss: 0.5678 - recall: 0.0834 - val_AUC: 0.6361 - val_accuracy: 0.7080 - val_loss: 0.5795 - val_recall: 0.0513
# Epoch 36/100
# 240/240 - 2s - 9ms/step - AUC: 0.6616 - accuracy: 0.7178 - loss: 0.5671 - recall: 0.0941 - val_AUC: 0.6349 - val_accuracy: 0.7088 - val_loss: 0.5803 - val_recall: 0.0537
# Epoch 37/100
# 240/240 - 2s - 9ms/step - AUC: 0.6650 - accuracy: 0.7180 - loss: 0.5644 - recall: 0.0987 - val_AUC: 0.6337 - val_accuracy: 0.7076 - val_loss: 0.5807 - val_recall: 0.0574
# Epoch 38/100
# 240/240 - 2s - 10ms/step - AUC: 0.6623 - accuracy: 0.7165 - loss: 0.5663 - recall: 0.0977 - val_AUC: 0.6365 - val_accuracy: 0.7094 - val_loss: 0.5791 - val_recall: 0.0523
# Epoch 39/100
# 240/240 - 3s - 11ms/step - AUC: 0.6648 - accuracy: 0.7176 - loss: 0.5652 - recall: 0.0956 - val_AUC: 0.6389 - val_accuracy: 0.7092 - val_loss: 0.5780 - val_recall: 0.0510
# Epoch 40/100
# 240/240 - 3s - 13ms/step - AUC: 0.6651 - accuracy: 0.7184 - loss: 0.5646 - recall: 0.0987 - val_AUC: 0.6351 - val_accuracy: 0.7097 - val_loss: 0.5807 - val_recall: 0.0704
# Epoch 41/100
# 240/240 - 3s - 12ms/step - AUC: 0.6664 - accuracy: 0.7171 - loss: 0.5642 - recall: 0.0996 - val_AUC: 0.6352 - val_accuracy: 0.7095 - val_loss: 0.5803 - val_recall: 0.0551
# Epoch 42/100
# 240/240 - 3s - 13ms/step - AUC: 0.6682 - accuracy: 0.7176 - loss: 0.5637 - recall: 0.0947 - val_AUC: 0.6369 - val_accuracy: 0.7084 - val_loss: 0.5791 - val_recall: 0.0544
# Epoch 43/100
# 240/240 - 3s - 11ms/step - AUC: 0.6703 - accuracy: 0.7185 - loss: 0.5618 - recall: 0.1075 - val_AUC: 0.6336 - val_accuracy: 0.7091 - val_loss: 0.5802 - val_recall: 0.0574
# Epoch 44/100
# 240/240 - 3s - 11ms/step - AUC: 0.6689 - accuracy: 0.7177 - loss: 0.5631 - recall: 0.0988 - val_AUC: 0.6371 - val_accuracy: 0.7084 - val_loss: 0.5785 - val_recall: 0.0595
# Epoch 45/100
# 240/240 - 2s - 10ms/step - AUC: 0.6710 - accuracy: 0.7176 - loss: 0.5623 - recall: 0.1021 - val_AUC: 0.6372 - val_accuracy: 0.7091 - val_loss: 0.5785 - val_recall: 0.0568
# Epoch 46/100
# 240/240 - 3s - 13ms/step - AUC: 0.6747 - accuracy: 0.7179 - loss: 0.5607 - recall: 0.1074 - val_AUC: 0.6356 - val_accuracy: 0.7085 - val_loss: 0.5805 - val_recall: 0.0622
# Epoch 47/100
# 240/240 - 3s - 12ms/step - AUC: 0.6739 - accuracy: 0.7197 - loss: 0.5606 - recall: 0.1168 - val_AUC: 0.6374 - val_accuracy: 0.7075 - val_loss: 0.5810 - val_recall: 0.0707
# Epoch 48/100
# 240/240 - 3s - 11ms/step - AUC: 0.6743 - accuracy: 0.7192 - loss: 0.5608 - recall: 0.1140 - val_AUC: 0.6369 - val_accuracy: 0.7091 - val_loss: 0.5798 - val_recall: 0.0595
# Epoch 49/100
# 240/240 - 3s - 12ms/step - AUC: 0.6782 - accuracy: 0.7201 - loss: 0.5592 - recall: 0.1161 - val_AUC: 0.6370 - val_accuracy: 0.7088 - val_loss: 0.5792 - val_recall: 0.0707
# ['/Users/audreychang/projects/ACTL3143/Actl3143-report2/data/history_widedeep.pkl']
